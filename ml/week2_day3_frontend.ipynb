# %%
# ================================================
# WEEK 2 DAY 3 — HTML Frontend for ML API
# Phetho Tlaka | April 2026
#
# WHAT WE BUILT:
# A full HTML web frontend that connects to
# our FastAPI prediction API
#
# FILE: frontend/predictor.html
#
# TECHNOLOGIES USED:
# HTML  — structure (form, buttons, result card)
# CSS   — dark theme styling and animations
# JS    — fetch API to call our FastAPI endpoint
#
# HOW IT WORKS:
# 1. User fills in passenger details on the form
# 2. Click "Predict Survival"
# 3. JavaScript sends data to FastAPI via HTTP POST
# 4. API returns prediction as JSON
# 5. Result shown with animated probability bar
#
# KEY CONCEPTS LEARNED:
# fetch() — send HTTP requests from JavaScript
# JSON    — data format between frontend and API
# CORS    — allow browser to call different port
# async/await — handle responses without freezing
# DOM     — update page content from JavaScript
# ================================================

print("=" * 52)
print("  WEEK 2 DAY 3 — Frontend Summary")
print("=" * 52)
print()
print("Files built:")
print("  frontend/predictor.html")
print()
print("How the frontend talks to the API:")
print()
print("  User fills form")
print("  → JS collects values")
print("  → fetch POST to http://192.168.10.116:8000/predict")
print("  → API returns JSON prediction")
print("  → JS updates the result card on screen")
print()
print("JavaScript fetch pattern:")
print("""
  const response = await fetch(API + '/predict', {
      method: 'POST',
      headers: {'Content-Type': 'application/json'},
      body: JSON.stringify({pclass, sex, age, fare...})
  })
  const data = await response.json()
  // data.prediction = "SURVIVED"
  // data.confidence = "99.0%"
""")
print("Error handling:")
print("  ✓ API unreachable → clear error message")
print("  ✓ Invalid input  → validation error shown")
print("  ✓ 422 from API   → detail message shown")
print()
print("Stack after Day 3:")
print("  predictor.html → FastAPI → Random Forest")
